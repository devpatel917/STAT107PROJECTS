# %% [markdown]
# # Welcome to Lab_Plots!
#
# You may not know this, but the salaries of the employees at the University of Illinois are publicly available! We have curated this data in a nice, structured dataset called `graybook.csv` for you to explore.  The goal of this lab is to work with real UIUC salary data to explore its properties, answer important questions, and to think about the implications of collecting and analyzing this data.  Throughout the lab, it is important to think about being a critical consumer of data who can not only use statistics and programming to analyze data but can also think about the "why" part of data science both in the classroom and in the world. Let’s get started!
#
# In this lab, you will:
#
# - Work with real UIUC salary data to explore some of the statistics that we talked about in class: mean, median, standard deviation, etc.
# - Practice creating plots to visualize quantitative data: boxplots and histograms.
# - See how data science can be used in the real world to think about important issues through individual reflection and discussions with your group.

# %% [markdown]
# ## PRE-LAB SURVEY
#
# We are doing a pre and post lab survey this week! Please complete this survey BEFORE you start the lab to get +2 extra credit points! Who doesn't want extra credit?!  This will help us make the labs better and should take about 5 minutes :) Click the link below to access the survey.
#
# [https://forms.gle/ouMaFuucdJHXKVza7](https://forms.gle/ouMaFuucdJHXKVza7)

# %% [markdown]
# ## 000. Your Group
#
# Edit the next Python cell to add information about who you're working within your lab section:

# %%
partner1_name = "Dev"
partner1_netid = "devhp2"
partner1_major = "Statistics"

partner2_name = "Collin"
partner2_netid = "collinmc3"
partner2_major = "Statistics"

partner3_name = "Sam"
partner3_netid = "sstef3"
partner3_major = "Statistics"

# %% [markdown]
# ## 00. Install MatPlotLib
#
# In this lab, we will be creating two types of simple visualizations: Histograms and Box Plots.  To do this, we need to make sure `matplotlib` is installed.
#
# Pull up your terminal and run the following code:
#
# MAC USERS:
#
# python3 -mpip install matplotlib
#
#
# WINDOWS USERS:
#
# py -m pip install matplotlib

# %% [markdown]
# ## 0. Import the Data
#
# In the same directory as this notebook, find the dataset called `graybook.csv` that is provided.  We will use the other dataset later on ;) You know what to do to import the libraries and read in the data! :)
#
# Look at the variable names, how many rows and columns there, and anything else you may notice!

# %%
#import the graybook.csv dataset below 
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("graybook.csv")
df
# Out:
#                                  Employee Name  Academic Title  \
# 0                              Edakara, Manu I             NaN
# 1                         Quarton, John Edward             NaN
# 2                        Werpetinski, Valeri A             NaN
# 3                   Abdel-Khalik, Ahmed Rashad            PROF
# 4                                 Ahmed, Waqar        LECTURER
# 5                             Anand, Vikrant V       ASST PROF
# 6                          Anderson, Spencer B       ASST PROF
# 7     Augusto Sampaio Franco de Lima, Gerlando     SR LECTURER
# 8                               Brown, Nerissa      ASSOC PROF
# 9                             Brown, Timothy J       ASST PROF
# 10                           Brunner, Robert J            PROF
# 11                           Chatterton, Angel   SR INSTRUCTOR
# 12                              Chen, Ciao-Wei       ASST PROF
# 13                              Chen, Xiaoling            PROF
# 14                            Ciconte, William       ASST PROF
# 15                    Curtis, Susan Mertzlufft        LECTURER
# 16                          Davis, Gregory Lee        LECTURER
# 17                                Davis, Jon S            PROF
# 18                          Donohoe, Michael P      ASSOC PROF
# 19                                     Du, Fei       ASST PROF
# 20                           Elliott, W Brooke            PROF
# 21                       Fanning, Kirsten Beth       ASST PROF
# 22                            Finnegan, Thomas        LECTURER
# 23                          Fisher, Mitchell B      INSTRUCTOR
# 24                           Frizzell, Allyson             NaN
# 25                              Glynn, Amber E             NaN
# 26                              Godsell, David       ASST PROF
# 27                           Hamm, Brian Keith       ASST PROF
# 28                             Hayne, Christie       ASST PROF
# 29                         Hecht, Gary William      ASSOC PROF
# ...                                        ...             ...
# 3525                           Sachdev, Vishal             NaN
# 3526                        Sanders, William H            PROF
# 3527            Santos Gilbertz, Rosa Milagros            PROF
# 3528                        Sather, Carl Allen  CLIN ASST PROF
# 3529                 Savonius-Wroth, Celestina       ASST PROF
# 3530                          Schantz, Susan L            PROF
# 3531                           Schatz, Bruce R            PROF
# 3532                         Schneider, Jodi A       ASST PROF
# 3533                      Seidel, Harry Edward        RES PROF
# 3534                           Smith, Denise L             NaN
# 3535                  Sotomayor Carlo, Antonio       ASST PROF
# 3536                              Sroka, Marek            PROF
# 3537               Stewart de Ramirez, Sarah A      ASSOC PROF
# 3538                         Stodden, Victoria      ASSOC PROF
# 3539                       Szylowicz, Caroline      ASSOC PROF
# 3540                     Tappenden, Kelly Anne            PROF
# 3541                        Tapping, Richard I            PROF
# 3542              Teran-Garcia, Margarita De L   RES ASST PROF
# 3543                           Tilley, Carol L      ASSOC PROF
# 3544             Tussing-Humphreys, Lisa Marie       ASST PROF
# 3545                  Twidale, Michael Bernard            PROF
# 3546                       Von Thaden, Terry L       ASST PROF
# 3547                         Vozenilek, John A            PROF
# 3548                    Weathersby, Deidre Ann  ADJ INSTRUCTOR
# 3549                       Wilson, Barbara Jan            PROF
# 3550                             Wolfson, Ouri            PROF
# 3551                           Wu, Maryalice S   ADJ ASST PROF
# 3552                              Yau, Peter M   RES ASST PROF
# 3553                              Yodh, Jaya G   RES ASST PROF
# 3554                             Zerai, Assata            PROF
#
#                   Primary Job Title Primary College  \
# 0         ASSOC DIR ENTREPRNRL CMTY        Business
# 1      SR DIR INNOVA ENTRPRNRL PRGM        Business
# 2     VST ASSOC DIR, ENTRPRNRL EDUC        Business
# 3                              PROF        Business
# 4                          LECTURER        Business
# 5                         ASST PROF        Business
# 6                         ASST PROF        Business
# 7                       SR LECTURER        Business
# 8                        ASSOC PROF        Business
# 9                         ASST PROF        Business
# 10                             PROF        Business
# 11                    SR INSTRUCTOR        Business
# 12                        ASST PROF        Business
# 13                             PROF        Business
# 14                        ASST PROF        Business
# 15                         LECTURER        Business
# 16                         LECTURER        Business
# 17                             PROF        Business
# 18                       ASSOC PROF        Business
# 19                        ASST PROF        Business
# 20                             PROF        Business
# 21                        ASST PROF        Business
# 22                         LECTURER        Business
# 23                       INSTRUCTOR        Business
# 24                 ACADEMIC ADVISOR        Business
# 25                 ACADEMIC ADVISOR        Business
# 26                        ASST PROF        Business
# 27               CLINICAL ASST PROF        Business
# 28                        ASST PROF        Business
# 29                       ASSOC PROF        Business
# ...                             ...             ...
# 3525                            ???             ???
# 3526                            ???             ???
# 3527                            ???             ???
# 3528                            ???             ???
# 3529                            ???             ???
# 3530                            ???             ???
# 3531                            ???             ???
# 3532                            ???             ???
# 3533                            ???             ???
# 3534                            ???             ???
# 3535                            ???             ???
# 3536                            ???             ???
# 3537                            ???             ???
# 3538                            ???             ???
# 3539                            ???             ???
# 3540                            ???             ???
# 3541                            ???             ???
# 3542                            ???             ???
# 3543                            ???             ???
# 3544                            ???             ???
# 3545                            ???             ???
# 3546                            ???             ???
# 3547                            ???             ???
# 3548                            ???             ???
# 3549                            ???             ???
# 3550                            ???             ???
# 3551                            ???             ???
# 3552                            ???             ???
# 3553                            ???             ???
# 3554                            ???             ???
#
#                   Primary Department     Salary  PrevFTE   FTE  \
# 0     Academy Entrepreneurial Ldrshp   66300.00     1.00  1.00
# 1     Academy Entrepreneurial Ldrshp  150480.70     1.00  1.00
# 2     Academy Entrepreneurial Ldrshp   71400.00     1.00  1.00
# 3                        Accountancy  318007.00     1.00  1.00
# 4                        Accountancy   96691.00     1.00  1.00
# 5                        Accountancy  227553.00     1.00  1.00
# 6                        Accountancy  216342.00     1.00  1.00
# 7                        Accountancy  147900.00     1.00  1.00
# 8                        Accountancy  255000.00     1.00  1.00
# 9                        Accountancy  225000.00     1.00  1.00
# 10                       Accountancy  280000.00     1.00  1.00
# 11                       Accountancy  133869.78     1.00  1.00
# 12                       Accountancy  225000.00     1.00  1.00
# 13                       Accountancy  298098.00     1.00  1.00
# 14                       Accountancy  216465.00     1.00  1.00
# 15                       Accountancy  112241.00     1.00  1.00
# 16                       Accountancy  139679.00     1.00  1.00
# 17                       Accountancy  379962.00     1.00  1.00
# 18                       Accountancy  257500.00     1.00  1.00
# 19                       Accountancy  237500.00     1.00  1.00
# 20                       Accountancy  344073.00     1.00  1.00
# 21                       Accountancy  211064.00     1.00  1.00
# 22                       Accountancy  112290.00     1.00  1.00
# 23                       Accountancy  111609.01     1.00  1.00
# 24                       Accountancy   48426.00     1.00  1.00
# 25                       Accountancy   48909.00     1.00  1.00
# 26                       Accountancy  219300.00     1.00  1.00
# 27                       Accountancy  123250.00     0.85  0.85
# 28                       Accountancy  219300.00     1.00  1.00
# 29                       Accountancy  287500.00     1.00  1.00
# ...                              ...        ...      ...   ...
# 3525                             ???    7500.00     0.00  0.00
# 3526                             ???  387000.00     1.00  0.00
# 3527                             ???  177096.00     0.00  0.00
# 3528                             ???       0.00     0.00  0.00
# 3529                             ???   80627.00     0.00  0.00
# 3530                             ???  151441.58     0.00  0.00
# 3531                             ???  171299.92     0.00  0.00
# 3532                             ???   81148.20     0.00  0.00
# 3533                             ???  395200.00     0.00  0.00
# 3534                             ???   36736.78     0.00  0.00
# 3535                             ???   66776.70     0.00  0.00
# 3536                             ???   92328.65     0.00  0.00
# 3537                             ???  146625.00     0.00  0.00
# 3538                             ???  105286.54     0.00  0.00
# 3539                             ???   72853.05     0.00  0.00
# 3540                             ???  168000.00     0.00  0.00
# 3541                             ???  178000.00     0.00  0.00
# 3542                             ???       0.00     0.00  0.00
# 3543                             ???   89421.49     0.00  0.00
# 3544                             ???  123062.53     0.00  0.00
# 3545                             ???  153413.70     0.00  0.00
# 3546                             ???  110421.71     0.00  0.00
# 3547                             ???   78717.84     0.00  0.00
# 3548                             ???   95981.61     0.00  0.00
# 3549                             ???  459000.00     0.00  0.00
# 3550                             ???  200456.78     0.00  0.00
# 3551                             ???   81962.71     0.00  0.00
# 3552                             ???  131447.50     0.00  0.00
# 3553                             ???  112200.00     0.00  0.00
# 3554                             ???  187530.00     0.00  0.00
#
#                                              All Titles   Empl Class  \
# 0                         ['ASSOC DIR ENTREPRNRL CMTY']       ['BA']
# 1     ['SR DIR INNOVA ENTRPRNRL PRGM' 'DIR HOEFT T&M...       ['BA']
# 2                     ['VST ASSOC DIR, ENTRPRNRL EDUC']       ['BA']
# 3             ['DIR CIERA' 'PROF' 'V K ZIMMERMAN PROF']  ['BC' 'AA']
# 4                                          ['LECTURER']       ['AA']
# 5        ['ASST PROF' 'RC EVANS DATA ANALYTICS FELLOW']       ['AA']
# 6                                         ['ASST PROF']       ['AA']
# 7                                       ['SR LECTURER']       ['AA']
# 8                   ['ASSOC PROF' 'PWC FACULTY FELLOW']       ['AA']
# 9                                         ['ASST PROF']       ['AA']
# 10    ['PROF' 'ARTHUR ANDERSEN FACULTY FELLOW' 'DIR ...  ['AA' 'BA']
# 11     ['ACADEMIC DIR BSA/MAS PROGRAM' 'SR INSTRUCTOR']  ['BA' 'AA']
# 12                                        ['ASST PROF']       ['AA']
# 13    ['DIR PHD PROGRAM' 'FV ROEDGERS FACULTY FELLOW...  ['BC' 'AA']
# 14                                        ['ASST PROF']       ['AA']
# 15                                         ['LECTURER']       ['AA']
# 16                                         ['LECTURER']       ['AA']
# 17              ['PROF' 'ROBERT C EVANS ENDOWED CHAIR']       ['AA']
# 18                  ['ASSOC PROF' 'PWC FACULTY FELLOW']       ['AA']
# 19       ['ASST PROF' 'RC EVANS DATA ANALYTICS FELLOW']       ['AA']
# 20    ['ERNST & YOUNG DIST PROF' 'HEAD ACCOUNTANCY' ...  ['AA' 'BC']
# 21                                        ['ASST PROF']       ['AA']
# 22                                         ['LECTURER']       ['AA']
# 23                                       ['INSTRUCTOR']       ['AA']
# 24                                 ['ACADEMIC ADVISOR']       ['BA']
# 25                                 ['ACADEMIC ADVISOR']       ['BA']
# 26                                        ['ASST PROF']       ['AA']
# 27                               ['CLINICAL ASST PROF']       ['AA']
# 28                                        ['ASST PROF']       ['AA']
# 29    ['ACADEMIC DIR IMSA PRGM' 'ASSOC PROF' 'PWC FA...  ['BA' 'AA']
# ...                                                 ...          ...
# 3525                        ['RC EVANS DATA ANALYTICS']       ['AA']
# 3526                   ['PROF' 'PROF, CSL' 'PROF, ITI']       ['AA']
# 3527                                           ['PROF']       ['AA']
# 3528                                 ['CLIN ASST PROF']       ['AB']
# 3529                                      ['ASST PROF']       ['AA']
# 3530                                           ['PROF']       ['AA']
# 3531                                           ['PROF']       ['AA']
# 3532                               ['ASST PROF, HCESC']       ['AA']
# 3533                 ['RES PROF' 'FOUNDER PROF' 'PROF']       ['AA']
# 3534                                        ['RES SCI']       ['BB']
# 3535                                      ['ASST PROF']       ['AL']
# 3536                                           ['PROF']       ['AA']
# 3537                              ['ASSOC PROF, HCESC']       ['AL']
# 3538                   ['ASSOC PROF' 'ASSOC PROF, CSL']       ['AA']
# 3539                                     ['ASSOC PROF']       ['AL']
# 3540                                           ['PROF']       ['AA']
# 3541                                           ['PROF']       ['AA']
# 3542                                  ['RES ASST PROF']       ['AL']
# 3543                                     ['ASSOC PROF']       ['AA']
# 3544                                      ['ASST PROF']       ['AA']
# 3545                               ['PROF' 'PROF, ITI']       ['AA']
# 3546                                      ['ASST PROF']       ['AA']
# 3547                               ['CLIN PROF, HCESC']       ['AA']
# 3548                                 ['ADJ INSTRUCTOR']       ['AL']
# 3549             ['KATHRYN L B DALLENBACH PROF' 'PROF']       ['AA']
# 3550                                           ['PROF']       ['AA']
# 3551                                  ['ADJ ASST PROF']       ['AA']
# 3552                                  ['RES ASST PROF']       ['AL']
# 3553                                  ['RES ASST PROF']       ['AL']
# 3554                                           ['PROF']       ['AA']
#
#       PrevSalary
# 0       65000.00
# 1      147530.00
# 2       70000.00
# 3      312556.00
# 4       96691.00
# 5      222500.00
# 6      212100.00
# 7      145000.00
# 8      255000.00
# 9      208489.00
# 10     211800.00
# 11     131734.78
# 12     212100.00
# 13     281803.00
# 14     212221.00
# 15     111130.00
# 16     136940.00
# 17     373590.00
# 18     247500.00
# 19     222500.00
# 20     335073.00
# 21     208974.00
# 22     111178.00
# 23     109421.01
# 24      47476.00
# 25      47950.00
# 26     215000.00
# 27     123250.00
# 28     215000.00
# 29     270000.00
# ...          ...
# 3525     7500.00
# 3526   260905.00
# 3527   172777.00
# 3528        0.00
# 3529    78831.20
# 3530   147030.66
# 3531   171196.39
# 3532    79285.00
# 3533   380000.00
# 3534    36016.45
# 3535    65148.00
# 3536    78328.65
# 3537   146625.00
# 3538   103121.00
# 3539    71076.15
# 3540   165000.00
# 3541   176000.00
# 3542        0.00
# 3543    87368.33
# 3544   119885.95
# 3545   149671.90
# 3546   108256.58
# 3547    78185.98
# 3548    92960.40
# 3549   450000.00
# 3550   200456.78
# 3551    80355.60
# 3552   128617.91
# 3553   110000.00
# 3554   184441.29
#
# [3555 rows x 11 columns]

# %%
for col in df.columns:
    print(col)

print(df.size)
# Out:
# Employee Name
# Academic Title
# Primary Job Title
# Primary College
# Primary Department
# Salary
# PrevFTE
# FTE
# All Titles
# Empl Class
# PrevSalary
# 39105

# %% [markdown]
# **❓ Individual Reflection and Group Discussion ❓**
#
# Thinking about the variables in the dataset, what are two questions that you’d like to use data science to answer (ex. What is the mean salary of my home department?).  Type them below and then share at least one of your questions with your group and why you want to find the answer to it.

# %% [markdown]
# Double Click this cell to edit it!
#
# Question 1: What departments have the highest paying salaries? - This would be interesting to answer as it could give more insight into the prestige/relevance of that department at UIUC.
#
# Question 2: What is the standard deviation of all salaries? - This would be interesting to find because we could find how "spread out" the earnings of employees are.

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)
# As we discussed in lecture, the first step of any data analysis is to get familiar with your dataset.  Think about what this data can tell you and what variables are included.  Data scientists always start with this step.
#
#
# Let’s do some overall exploratory data analysis to get some baseline data to compare to.  Before you do the calculations, guess what you think the average salary is at UIUC. Enter your answer below.

# %% [markdown]
# Guess for Overall Average Salary: 80,000

# %% [markdown]
# ### Puzzle 1.1: Descriptive Statistics
#
# Next, using all of the data, find the following information:
#
# 1. the number of employees at UIUC
# 2. the mean salary
# 3. the median salary
# 4. the standard deviation

# %%
university_num_emp = len(df)
university_num_emp
# Out:
# 3555

# %%
university_mean_sal = df["Salary"].mean()
university_mean_sal
# Out:
# 101284.91668642375

# %%
university_median_sal = df["Salary"].median()
university_median_sal
# Out:
# 86995.0

# %%
university_std_sal = df["Salary"].std()
university_std_sal
# Out:
# 55129.29496464768

# %%
## == TEST CASES for Puzzle 1.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs with a message (with the emoji showing), you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
x = university_num_emp + university_mean_sal + university_median_sal + university_std_sal
y = ((university_mean_sal - university_median_sal) * university_std_sal) / university_num_emp

assert( abs(x - 246964.21165107167) < 1 ), "It looks like your calculations are off?"
assert( abs(y - 221601.415478511) < 1 ), "It looks like your calculations are off?"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# **❓ Individual Reflection ❓**
#
# Write a few sentences answering the following questions: Is the mean or median larger? Why do you think this might be the case? What does the standard deviation tell you in this context?

# %% [markdown]
# The mean is larger. This might be the case as the salary of all employees is positively skewed. The standard deviation tells us that there is a large spread between the salaries of employees.

# %% [markdown]
# ### Visual Displays of Data -- A Key Part of EDA!
#
# Now, we are a bit more familiar with the dataset and some summary statistics. Looking at overall descriptive statistics helps us summarize all of the observations in a column, rather than having to scroll through all of the observations!  However, descriptive statistics alone often don’t tell the whole story.
#
# In lecture, we will see Anscombe’s Quartet (a set of 4 datasets with the exact same descriptive statistics that look completely different when graphed). This shows us that visual displays of data are also a necessary and important part of exploratory data analysis.
#
# ### Puzzle 1.2: Histograms
#
# Let’s start by looking at one of the most simple, yet powerful visual displays of data, a histogram.  Histograms are used to show the overall shape of the data and they allow us to see frequencies.  Create a frequency histogram of the salaries at UIUC.

# %%
# create your histogram here
histogram = df["Salary"].plot.hist()
plt.show()

# %% [markdown]
# ### Puzzle 1.3: Boxplots
#
# Next, let’s look at another simple, yet power visualization: a boxplot! Create a boxplot of the overall salary data at UIUC.

# %%
# create your boxplot here
boxplot= df["Salary"].plot.box()
plt.show()

# %% [markdown]
# **❓ Group Discussion ❓**
#
# Discuss with your group whether you think a histogram or a boxplot or both best visualize the salary data.  There is no right answer to this question.  Explain why histograms, boxplots, or both are important and what they can tell us about the data.
#
# Why is it valuable to look at visual displays of salary data in general (as opposed to just looking at descriptive statistics like the mean and SD)?

# %% [markdown]
# A boxplot might be better to visualize the data because the data is probably spread out, so there may be some outliers which is easier to see in a boxplot. Visual displays of data are valuable because we can see the shape of the data itself, not a summary of it.

# %% [markdown]
# ## 2. Department-Level Data
#
# One of the interesting properties of the salary dataset is that you can see what department each professor is from and look at the same data at a department level.  In other words, you can calculate descriptive statistics and look at visual displays of data for each department.  Let’s explore whether or not there are salary discrepancies among a few departments.
#
# ### Puzzle 2.1
# There was a certain function you learned that will help you **group** all of the people in each department so you can find departmental aggregates.  In other words, you want to group by `'Primary Department'`.
#
# Next, instead of just grouping by a single aggregate, use **Python list syntax** to aggregate by `count`, `mean`, and `median` to find the mean and median salary, as well as the count for how many people are in each department.
#
# *(You can view technical docs here:
# https://pandas.pydata.org/pandas-docs/stable/reference/groupby.html)*

# %%
group = df.groupby("Primary Department")
agg_df = group.agg(['count', 'mean', 'median']).reset_index()


# Here, we only care about two columns so we are selecting those columns to be in our dataset
agg_df = agg_df[["Primary Department", "Salary"]]

# Display 5 random rows to make sure it works:
agg_df.sample(5)
# Out:
#                 Primary Department Salary
#                                     count           mean      median
# 68       Fine & Applied Arts Admin     27   74298.004815   74174.000
# 82   Human Dvlpmt & Family Studies     43   73734.806047   65149.000
# 36                       Chemistry     52  118442.674615   86989.195
# 73                         Geology     15   99222.554667   89700.000
# 72  Geography & Geographic InfoSci     13  119999.843077  104913.170

# %%
## == TEST CASES for Puzzle 2.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs with a message (with the emoji showing), you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(agg_df) == 140 ), "You should have 140 different departments.  Check to make sure you grouped the data?"
assert( "Salary" in agg_df ), "You must have a salary output"
assert( "mean" in agg_df["Salary"] ), "Make sure you have a mean in your salary"
assert( "count" in agg_df["Salary"] ), "Make sure you have a count in your salary"
assert( "median" in agg_df["Salary"] ), "Make sure you have a median in your salary"
assert( len(agg_df.columns) == 4 ), "Make sure you have ONLY the salary data and the department"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 2.2
#
# Let’s look at 3 different departments: The Department of English, The Department of Psychology, and The Department of Electrical & Computer Eng.  Find the mean and median salary for each of these departments.  We'll do the means first!

# %%
# Find the means


mean_English = agg_df[agg_df["Primary Department"] == "English"]["Salary"]["mean"].values[0]
print(mean_English)

mean_Psych = agg_df[agg_df["Primary Department"] == "Psychology"]["Salary"]["mean"].values[0]
print(mean_Psych)

mean_ECE = agg_df[agg_df["Primary Department"] == "Electrical & Computer Eng"]["Salary"]["mean"].values[0]
print(mean_ECE)
# Out:
# 96333.8584746
# 105536.000972
# 134629.325556

# %%
## == TEST CASES for Puzzle 2.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs with a message (with the emoji showing), you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
x = mean_English + mean_Psych + mean_ECE

assert( x > 336499 ), "It looks like your calculations are off?"
assert( x < 336500 ), "It looks like your calculations are off?"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 2.3
#
# Find the median salaries of the following departments: The Department of English, The Department of Psychology, and The Department of Electrical & Computer Eng.

# %%
# Find the medians

median_English = agg_df[agg_df["Primary Department"] == "English"]["Salary"]["median"].values[0]
print(median_English)

median_Psych = agg_df[agg_df["Primary Department"] == "Psychology"]["Salary"]["median"].values[0]
print(median_Psych)

median_ECE = agg_df[agg_df["Primary Department"] == "Electrical & Computer Eng"]["Salary"]["median"].values[0]
print(median_ECE)
# Out:
# 89514.08
# 88732.625
# 130301.0

# %%
## == TEST CASES for Puzzle 2.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs with a message (with the emoji showing), you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
y = median_English + median_Psych + median_ECE

assert( y > 308547 ), "It looks like your calculations are off?"
assert( y < 308548 ), "It looks like your calculations are off?"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# **❓ Individual Reflection❓**
#
# Are the means and medians drastically different from each other in each department and between each of the 3 departments? Think about why or why not. Are there any confounding variables that could be driving these differences?  Write a few sentences below.

# %% [markdown]
# The means and medians are somewhat different from each other and there is a noticeable difference between the means and medians of the three departments.
#
# The students in the department could be a confounding variable. More students in one department could mean better salary for that department's employees as they have to handle more students.

# %% [markdown]
# ### Puzzle 2.4
#
# Create a histogram of the salaries in your home department.  In other words, if your major is Statistics, you should have a histogram of all the salaries in the Statistics Department. Also, find the maximum and minimum salary in your home department. If you're undecided, pick a department you are interested in.

# %%
# histogram of your home department

histogramOne = df[df["Primary Department"] == "Statistics"]["Salary"].plot.hist()
plt.show()

# %%
#find the max and min salary for your home deparment

max_salary = df[df["Primary Department"] == "Statistics"]["Salary"].max()
print(max_salary)

min_salary = df[df["Primary Department"] == "Statistics"]["Salary"].min()
print(min_salary)
# Out:
# 180000.0
# 32500.0

# %% [markdown]
# **❓ Group Discussion ❓**
#
# Share the results with the people at your table. Do you notice any similarities or differences between departments?

# %% [markdown]
# One similarity is that the range of salaries (max - min) is quite high for the departments. This means that it's possibly that there are a wide range of salaries for mostly all departments at U of I.

# %% [markdown]
# ## 3. Genders and Salaries
#
# Data can often reveal systemic problems or discrimination. For example, in many companies, men and women are promoted at different rates.  Let’s look at a subset of the salary dataset to investigate whether or not there is a difference in salaries between faculty who identify as men and women in two departments. We have this data for the STAT and CS departments (Karle and Wade’s home departments) and have compiled it in a dataset called `statcssalaries.csv`. This data is also located in the same directory as this lab!

# %% [markdown]
# ### Puzzle 3.1
#
# Load the second dataset `statcssalaries.csv` and create two boxplots of the male salaries and female salaries in this dataset.

# %%
# load the dataset
dfTwo = pd.read_csv("statcssalaries.csv")

# create the two boxplots
histogramTwo = dfTwo[dfTwo["Gender"] == "M"]["Salary"].plot.box()
plt.show()

histogramThree = dfTwo[dfTwo["Gender"] == "F"]["Salary"].plot.box()
plt.show()

# %% [markdown]
# ### Puzzle 3.2
#
# Next, calculate the overall mean, median, and SD of the salaries for this data.

# %%
overall_mean = dfTwo["Salary"].mean()
print(overall_mean)

overall_median = dfTwo["Salary"].median()
print(overall_median)

overall_SD = dfTwo["Salary"].std()
print(overall_SD)
# Out:
# 121030.35902255638
# 110992.0
# 49959.50619890204

# %%
## == TEST CASES for Puzzle 3.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs with a message (with the emoji showing), you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
x = overall_median + overall_median + overall_SD
y = ((overall_mean - overall_median) * overall_SD) / overall_SD

assert( abs(x - 271945.50619890203) > 1 ), "It looks like your calculations are off?"
assert( (y - 10038.359022556397) < 1 ), "It looks like your calculations are off?"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# **❓ Group Discussion ❓**
#
# Discuss the results with your group.  Some questions to think about: Do the boxplots look similar or different? Are there any outliers? Do you think these results present a problem?  What are the implications of this analysis for faculty, students, and the university?

# %% [markdown]
# There are some high outliers for male salaries. The boxplots look quite different as Q1, Q2, and Q3 for male salaries is higher than that for female salaries. This does raise some questions as to whether there is gender discrimination related to salaries, but nothing definitve can be concluded.

# %% [markdown]
# **❓ Individual Reflection❓**
#
# As a student, do you think these are fair salaries or are they too low or too high?  Why do you think this?  How does this dataset impact you? Write down your thoughts below.

# %% [markdown]
# I think that these salaries are pretty fair, but I would like to see a more similar boxplot for both males and females. This dataset shows me that the type of work that faculty is doing is high quality because they are getting paid like it.

# %% [markdown]
# Double Click this cell to edit and type your answer to the individual reflection question!

# %% [markdown]
# ## 4. Exploring Your Own Interests
#
# At this point of the lab, we have investigated a lot of questions, however, these have been questions that we have told you to answer. As a data scientist, it is important to be able to use the data science skills that you learn in the classroom to answer real questions that you have.
#
# **❓ Individual Reflection ❓**
#
# Think about two questions that you have that have not been answered. Record them below.  Then, answer at least one of these questions using Python and either dataset.

# %% [markdown]
# Double Click this cell to edit!
#
# Unanswered Question 1: What departments have the highest paying salaries? - This would be interesting to answer as it could give more insight into the prestige/relevance of that department at UIUC.
#
# Unanswered Question 2: What is the standard deviation of all salaries? - This would be interesting to find because we could find how "spread out" the earnings of employees are.

# %%
# answer a question that you have using Python in this cell- it can be something simple!
# Question 1
university_std_sal = df["Salary"].std()
university_std_sal
# Out:
# 55129.29496464768

# %%
#Question 2 - which departments have the highest paying salaries (top 3)
group = df.groupby("Primary Department")
agg_df = group.agg("mean").reset_index()

group = agg_df.nlargest(3, "Salary")
group
# Out:
#            Primary Department         Salary   PrevFTE       FTE  \
# 127  Siebel Center for Design  300000.000000  1.000000  1.000000
# 67                    Finance  214339.776667  0.991538  0.991538
# 3                 Accountancy  188585.546119  0.984328  0.991791
#
#         PrevSalary
# 127  300000.000000
# 67   209043.042821
# 3    181665.919254

# %% [markdown]
# **❓ Group Discussion ❓**
#
# Share your question and results with your group.

# %% [markdown]
# ## 5. Counter Data
#
# As a data scientist, it is important to think about the implications of collecting and not collecting certain data.  Data that is not collected in an analysis is called *counter data*.
#
# Many times, data is collected to make a profit.  Data has even been referred to as “the new oil” because it is oftentimes seen as an uncapped natural resource and if you can figure out how to capture and refine it, it can lead to a massive profit.
#
# **❓ Group Discussion ❓**
# Chat in your groups about the following questions: What is some counter data that you’d like to collect in regard to salaries? Why do you think it’s important to collect this data?  Share your thoughts with your group.  Some examples of questions that would need counter data are listed below:
#
# - Do smaller colleges pay a lot less than big research universities?
# - How does UIUC compare to other similar schools in terms of what they pay their faculty?
# - Are there salary disparities if we stratify based on ethnicity?
# - How has this data changed over time?

# %% [markdown]
# Some countedata that we could collect is the amount of courses the employee is teacher and how much research he/she is part. These are all factors that could play a role in the salaries of faculty. We would also need to collect data on other schools to gain accurate comparison on gaining insight into paying patterns/behavior at UIUC. There are probably some salary disparities if we stratify based on ethnicity just because many of the CS professors and faculty could fall under a similar category.

# %% [markdown]
# **❓ Individual Reflection ❓**
#
# Now think about how you would actually go about collecting this data to answer a question that you have.  Respond below with the question you’d want to answer, the counter data you’d want to collect, what resources you’d need to collect it, and if this is realistic.

# %% [markdown]
# Double Click this cell to edit and type your answer to the individual reflection question!

# %% [markdown]
# 1. I want to collect data on the amount of courses each faculty member is teaching.
# 2. We could send out a google form/survey to all faculty members
# 3. This is realistic due to the power of the Internet and emailing
# 4. The data would be collected in a spreadsheet, which could later be converted to a csv for further analysis

# %% [markdown]
# ## 6. Beyond Stat 107
#
# As a Data Scientist, it’s important to think about who data analysis can benefit and who it can harm.  It’s also important to think about why the data is collected and why counter data is not collected.
#
# **❓ Group Discussion ❓**
#
# Who benefits from collecting this salary data?  Who does this data harm?
# Why do you think this salary data is public? Can you think of any reasons that this could be problematic?

# %% [markdown]
# This salary data could be problematic as it could cause controversay among students and parents - "why is a certain teacher getting a certain amount of salary." Students could be quick to judge their teachers' performance.
#
# This salary data could be helpful to someone who is in charge of finance and an employee is asking for a promotion.
#
# This data is public because people should be getting the money accordingly to what they do and their quality as well as quantity of work. Making it public ensures that no secrecy regarding the treatment of faculty members is being held.

# %% [markdown]
# **❓ Last Individual Reflection ❓**
#
# Let’s think beyond the salary data!  Thinking about the data science skills that you have mastered: experimental design, descriptive statistics, and basic visualization, what is one real world question that you’d like to answer using data?  It can be about anything, a hobby or a specific passion or issue.  You won’t be doing this, but instead thinking about how you’d do this. Write down your thoughts below.

# %% [markdown]
# I have a great passion in sports analytics, specifically NFL football. This could be using data to drive decisons or in football using data to win football games. One question I think I could answer is for any given team, what types of offensive plays have the highest likelihood of succeeding or greatest expected yards against a certain type of defensive coverage.

# %% [markdown]
# ## POST-LAB SURVEY
#
# Remember, we are doing a pre and post lab survey this week! Please complete this survey AFTER you finish the lab to get +2 additional extra credit points! This will also help us make the labs better and should take about 10 minutes :) Click the link below to access the survey.
#
# [https://forms.gle/5E33LkR24KgNoo6A8](https://forms.gle/5E33LkR24KgNoo6A8)

# %% [markdown]
# ## Submit Your Work

# %% [markdown]
# You're almost done -- congratulations! 🎉
#
# You need to do two more things:
#
# 1.  Save your work. To do this, go to File -> Save All
#
# 2.  After you have saved, exit this notebook and follow the webpage instructions to commit this lab to your Git repository!
